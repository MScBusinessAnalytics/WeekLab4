# %% [markdown]
# # Week 4 - Collecting data from Yahoo - use of yfinance
#
# ## What is API?
#
# API stands for application programming interface, which is a set of definitions and protocols for building and integrating application software. Most APIs require authorisation before the service provider will give you an assess token that allows you to call the API and pull the data. We will explore this in the next level of the exercise for fetching data from Twitter. In this basic level of the exercise, we will use a python library that integrates the authorisation process, which is very friendly to beginners.
#
# ## About yfinance
#
# Please visit the documentation of yfinance via this [link](https://pypi.org/project/yfinance/), and you should read the legal disclaimer before using the library. yfinance is a Python library that gives the public easy access to financial data available on [Yahoo Finance](https://uk.finance.yahoo.com/). One of the big advantages of this library is that it returns the data as Pandas DataFrames, which we introduced in last week's tutorial. In most cases we deal with APIs to pull the data; transforming data to an organised format is one of the most difficult parts. The library of yfinance has helped us to organise it properly, which is a plus for the beginner.
#
# ## The learning outcomes of this exercise
#
# 1. Using the public available library in Python;
# 2. Understanding the use of documentation of library to solve problem;
# 3. Collecting data and organise them properly in Python DataFrame;
#
# <img src="../Image/stocks-vs-market-wo.jpg" width=400 height=400 />

# %%
#importing the required library in this exercise

import pandas as pd
import yfinance as yf

# %% [markdown]
# ### 1. Retriving data based on company's Stock Ticker
#
# Simply put, the Stock Ticker is the comapany's ID number enables the analyst to retrieve data of the company. For lists of the Stock Ticker, you can visit this [link](https://www.nyse.com/listings_directory/stock) for the NYSE market and this [link](https://www.nasdaq.com/market-activity/stocks/screener) for the NASDAQ. The `Ticker` module, allows you to access the company's data through their Stock Ticker.
#
# With the library name `yf` we defined, we can use the module by typing `yf.Ticker("Insert The Ticker Symbol Here")`. I took Ford Morto as an example below:

# %%
FORD = yf.Ticker("F")

#utilising the .info function to retrive the background information of the company
FORD.info
# Out:
# {'zip': '48126-1899',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 183000,
#  'longBusinessSummary': 'Ford Motor Company designs, manufactures, markets, and services a range of Ford trucks, cars, sport utility vehicles, electrified vehicles, and Lincoln luxury vehicles worldwide. It operates through three segments: Automotive, Mobility, and Ford Credit. The Automotive segment sells Ford and Lincoln vehicles, service parts, and accessories through distributors and dealers, as well as through dealerships to commercial fleet customers, daily rental car companies, and governments. The Mobility segment designs and builds mobility services; and provides self-driving systems development services. The Ford Credit segment primarily engages in vehicle-related financing and leasing activities to and through automotive dealers. It provides retail installment sale contracts for new and used vehicles; and direct financing leases for new vehicles to retail and commercial customers, such as leasing companies, government entities, daily rental companies, and fleet customers. This segment also offers wholesale loans to dealers to finance the purchase of vehicle inventory; and loans to dealers to finance working capital and enhance dealership facilities, purchase dealership real estate, and other dealer vehicle programs. The company has a strategic collaboration with ARB Corporation Limited to develop a suite of aftermarket products for the new Ford Bronco. Ford Motor Company was incorporated in 1903 and is based in Dearborn, Michigan.',
#  'city': 'Dearborn',
#  'phone': '313 322 3000',
#  'state': 'MI',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://www.ford.com',
#  'maxAge': 1,
#  'address1': 'One American Road',
#  'fax': '313 845 6073',
#  'industry': 'Auto Manufacturers',
#  'ebitdaMargins': 0.1179,
#  'profitMargins': 0.078839995,
#  'grossMargins': 0.12194,
#  'operatingCashflow': 12401999872,
#  'revenueGrowth': 0.502,
#  'operatingMargins': 0.07817,
#  'ebitda': 17451999232,
#  'targetLowPrice': 10,
#  'recommendationKey': 'hold',
#  'grossProfits': 16507000000,
#  'freeCashflow': 13603749888,
#  'targetMedianPrice': 13,
#  'currentPrice': 11.77,
#  'earningsGrowth': 0.143,
#  'currentRatio': 1.162,
#  'returnOnAssets': 0.029260002,
#  'numberOfAnalystOpinions': 19,
#  'targetMeanPrice': 15.01,
#  'debtToEquity': 294.401,
#  'returnOnEquity': 0.29395,
#  'targetHighPrice': 28,
#  'totalCash': 28216000512,
#  'totalDebt': 130233999360,
#  'totalRevenue': 148026998784,
#  'totalCashPerShare': 7.018,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 36.961,
#  'quickRatio': 0.954,
#  'recommendationMean': 2.7,
#  'exchange': 'NYQ',
#  'shortName': 'Ford Motor Company',
#  'longName': 'Ford Motor Company',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'F',
#  'messageBoardId': 'finmb_106335',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 1.016,
#  'beta3Year': None,
#  'enterpriseToEbitda': 8.621,
#  '52WeekChange': -0.277027,
#  'morningStarRiskRating': None,
#  'forwardEps': 1.87,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 3949390080,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 10.987,
#  'sharesShort': 134184567,
#  'sharesPercentSharesOut': 0.0334,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.48547,
#  'netIncomeToCommon': 11671000064,
#  'trailingEps': 2.94,
#  'lastDividendValue': 0.15,
#  'SandP52WeekChange': -0.19343,
#  'priceToBook': 1.071266,
#  'heldPercentInsiders': 0.00206,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1656547200,
#  'shortRatio': 1.77,
#  'sharesShortPreviousMonthDate': 1661904000,
#  'floatShares': 3937983458,
#  'beta': 1.378776,
#  'enterpriseValue': 150449455104,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 965260800,
#  'lastSplitFactor': '1748175:1000000',
#  'legalType': None,
#  'lastDividendDate': 1660089600,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.189,
#  'priceToSalesTrailing12Months': 0.3196594,
#  'dateShortInterest': 1664496000,
#  'pegRatio': 0.43,
#  'ytdReturn': None,
#  'forwardPE': 6.294118,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.037,
#  'sharesShortPriorMonth': 108396319,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 12.13,
#  'regularMarketOpen': 12.13,
#  'twoHundredDayAverage': 15.2203,
#  'trailingAnnualDividendYield': 0.02473207,
#  'payoutRatio': 0.1038,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 12.195,
#  'navPrice': None,
#  'averageDailyVolume10Day': 65520080,
#  'regularMarketPreviousClose': 12.13,
#  'fiftyDayAverage': 13.881,
#  'trailingAnnualDividendRate': 0.3,
#  'open': 12.13,
#  'toCurrency': None,
#  'averageVolume10days': 65520080,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 0.6,
#  'exDividendDate': 1660089600,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 11.73,
#  'currency': 'USD',
#  'trailingPE': 4.0034013,
#  'regularMarketVolume': 54774134,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 47318224896,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 69894756,
#  'dayLow': 11.73,
#  'ask': 11.73,
#  'askSize': 21500,
#  'volume': 54774134,
#  'fiftyTwoWeekHigh': 25.87,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 10.61,
#  'bid': 11.53,
#  'tradeable': False,
#  'dividendYield': 0.0499,
#  'bidSize': 38800,
#  'dayHigh': 12.195,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 11.77,
#  'preMarketPrice': 11.61,
#  'logo_url': 'https://logo.clearbit.com/ford.com'}

# %% [markdown]
# ### 2. Defining our observation period
#
# In the sampling process, we always specify a time frame to make our data collection more efficiently. The function of `.history` will help us to specify the details and we can check the detailed statment of the following parameters:
#
#         period : str
#             Valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
#             Either Use period parameter or use start and end
#         interval : str
#             Valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
#             Intraday data cannot extend last 60 days
#         start: str
#             Download start date string (YYYY-MM-DD) or _datetime.
#             Default is 1900-01-01
#         end: str
#             Download end date string (YYYY-MM-DD) or _datetime.
#             Default is now
#         prepost : bool
#             Include Pre and Post market data in results?
#             Default is False
#         auto_adjust: bool
#             Adjust all OHLC automatically? Default is True
#         back_adjust: bool
#             Back-adjusted data to mimic true historical prices
#         proxy: str
#             Optional. Proxy server URL scheme. Default is None
#         rounding: bool
#             Round values to 2 decimal places?
#             Optional. Default is False = precision suggested by Yahoo!
#         tz: str
#             Optional timezone locale for dates.
#             (default data is returned as non-localized dates)
#         timeout: None or float
#             If not None stops waiting for a response after given number of
#             seconds. (Can also be a fraction of a second e.g. 0.01)
#             Default is None.
#
# **We use default setting for nearly all the peremeters here, but we'd like to change the period or dates and the interval.**

# %%
#Downlaoding the most recent three months' daily stock market data

FORD = yf.Ticker('F')
FORD_Three_Months = FORD.history(period = '3mo', interval = '1d')
FORD_Three_Months
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2022-07-19 00:00:00-04:00  12.099328  12.564686  12.089427  12.465674
# 2022-07-20 00:00:00-04:00  12.475576  12.693403  12.386465  12.604292
# 2022-07-21 00:00:00-04:00  12.752811  12.871626  12.505280  12.871626
# 2022-07-22 00:00:00-04:00  12.970639  13.010244  12.594391  12.693403
# 2022-07-25 00:00:00-04:00  12.723108  12.861725  12.475576  12.713206
# ...                              ...        ...        ...        ...
# 2022-10-12 00:00:00-04:00  11.480000  11.700000  11.350000  11.540000
# 2022-10-13 00:00:00-04:00  11.240000  11.890000  11.200000  11.770000
# 2022-10-14 00:00:00-04:00  11.800000  11.850000  11.560000  11.670000
# 2022-10-17 00:00:00-04:00  11.980000  11.990000  11.660000  11.830000
# 2022-10-18 00:00:00-04:00  12.220000  12.250000  11.910000  12.030000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2022-07-19 00:00:00-04:00  62650800        0.0             0
# 2022-07-20 00:00:00-04:00  51932200        0.0             0
# 2022-07-21 00:00:00-04:00  66949200        0.0             0
# 2022-07-22 00:00:00-04:00  46724700        0.0             0
# 2022-07-25 00:00:00-04:00  36830500        0.0             0
# ...                             ...        ...           ...
# 2022-10-12 00:00:00-04:00  59628500        0.0             0
# 2022-10-13 00:00:00-04:00  70487400        0.0             0
# 2022-10-14 00:00:00-04:00  55127700        0.0             0
# 2022-10-17 00:00:00-04:00  59561700        0.0             0
# 2022-10-18 00:00:00-04:00  53465800        0.0             0
#
# [65 rows x 7 columns]

# %% [markdown]
# ### 2.Q. Exercise of downloading stock price data and visualising it
#
# **<span style="color:green">Now it's your turn to practice: Can you download the hourly stock price reaction (in one week) of Apple releasing iPhone 14/14 pro?</span>**
#
# Hint: You will need to check the releasing date of iphone model and adjust the peremeter in  `history`. Please use the unvealing date of the models not the launching date for sales.

# %%
#Please show your code of downloading the data below

APPL = yf.Ticker('AAPL')
APPL_iphone14 = APPL.history(interval='1h', start = '2022-09-07', end='2022-09-14')

# %%
#Please complete the code to visualise the stock price reactions of two models

import matplotlib.pyplot as plt
APPL_iphone14['Open'].plot(label = 'iphone14', figsize = (15,7))
plt.title('iphone 14 stock market reaction')
# Out:
# Text(0.5, 1.0, 'iphone 14 stock market reaction')

# %% [markdown]
# ### 3. Extracting Fundamental Data
#
# To conduct industrial research or academic study, the fundamental data (normally reported in annual report/earning reports) such as firm's revenue, cost of good sold, and R&D investement are heavily used.
#
# The financial data can be extracted through the method of `.financials`.

# %%
FORD = yf.Ticker('F')
FORD_financials = FORD.financials
FORD_financials
# Out:
#                                             2021-12-31      2020-12-31  \
# Research Development                              None            None
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        17780000000.0   -1116000000.0
# Minority Interest                          103000000.0     121000000.0
# Net Income                               17937000000.0   -1279000000.0
# Selling General Administrative            5918000000.0   10124000000.0
# Gross Profit                             16507000000.0    6123000000.0
# Ebit                                     10589000000.0   -4001000000.0
# Operating Income                         10589000000.0   -4001000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -1803000000.0   -1651000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                        -130000000.0     160000000.0
# Total Revenue                           136341000000.0  127144000000.0
# Total Operating Expenses                125752000000.0  131145000000.0
# Cost Of Revenue                         119834000000.0  121021000000.0
# Total Other Income Expense Net            7191000000.0    2885000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops           17910000000.0   -1276000000.0
# Net Income Applicable To Common Shares   17937000000.0   -1279000000.0
#
#                                             2019-12-31      2018-12-31
# Research Development                              None            None
# Effect Of Accounting Charges                      None            None
# Income Before Tax                         -640000000.0    4345000000.0
# Minority Interest                           45000000.0     134000000.0
# Net Income                                  47000000.0    3677000000.0
# Selling General Administrative           12763000000.0    9781000000.0
# Gross Profit                             12876000000.0   14835000000.0
# Ebit                                       113000000.0    5054000000.0
# Operating Income                           113000000.0    5054000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -1049000000.0   -1228000000.0
# Extraordinary Items                               None            None
# Non Recurring                                     None            None
# Other Items                                       None            None
# Income Tax Expense                        -724000000.0     650000000.0
# Total Revenue                           155900000000.0  160338000000.0
# Total Operating Expenses                155787000000.0  155284000000.0
# Cost Of Revenue                         143024000000.0  145503000000.0
# Total Other Income Expense Net            -753000000.0    -709000000.0
# Discontinued Operations                           None            None
# Net Income From Continuing Ops              84000000.0    3695000000.0
# Net Income Applicable To Common Shares      47000000.0    3677000000.0

# %% [markdown]
# ### 3.Q. Exercise of downloading financial data for a single company
#
# **<span style="color:green">Now it's your turn to practice: Can you download the balancesheet and cash flow data of FORD and integrated all three Dataframes including the Financials in last example?</span>**
#
# Hint: To extract the data from balancesheet and cashflow, you will use the methods of `.balancesheet` and `.cashflow`. To merge data frame, you will use `.concat` in pandas. `.to_csv` is the method for exporting dataframe to csv file.

# %%
#Please show your code of integrating the financials, balancesheet, and cashflow below:

FORD_financials = FORD.financials
FORD_balancesheet = FORD.balancesheet
FORD_cashflow = FORD.cashflow
FORD_integrate = pd.concat([FORD_financials,FORD_balancesheet,FORD_cashflow])
print(FORD_integrate)

#Can you save the integrated DataFrame as a CSV file?
FORD_integrate.to_csv('FORD_integrate.csv')
# Out:
#                                               2021-12-31    2020-12-31  \
# Research Development                                None          None
# Effect Of Accounting Charges                        None          None
# Income Before Tax                          17780000000.0 -1116000000.0
# Minority Interest                            103000000.0   121000000.0
# Net Income                                 17937000000.0 -1279000000.0
# ...                                                  ...           ...
# Change To Account Receivables              -1141000000.0   -63000000.0
# Other Cashflows From Financing Activities   -105000000.0  -184000000.0
# Change To Netincome                       -12489000000.0  -762000000.0
# Capital Expenditures                       -6227000000.0 -5742000000.0
# Repurchase Of Stock                                  NaN           NaN
#
#                                              2019-12-31    2018-12-31
# Research Development                               None          None
# Effect Of Accounting Charges                       None          None
# Income Before Tax                          -640000000.0  4345000000.0
# Minority Interest                            45000000.0   134000000.0
# Net Income                                   47000000.0  3677000000.0
# ...                                                 ...           ...
# Change To Account Receivables              -816000000.0 -2239000000.0
# Other Cashflows From Financing Activities  -226000000.0  -192000000.0
# Change To Netincome                        2898000000.0  1626000000.0
# Capital Expenditures                      -7632000000.0 -7785000000.0
# Repurchase Of Stock                        -237000000.0  -164000000.0
#
# [70 rows x 4 columns]

# %% [markdown]
# ### 4. Dealing with multiple companies in data collection
#
# To have a comprehensive picture of the industry/competitors, we always want to explore the patterns behind multiple companies. In the below example, we will create a list of company for the data collection.

# %%
tickerStrings = ['AMZN','NFLX']
df_list = list() # creating an empty list
for ticker in tickerStrings:
    data = yf.download(ticker, group_by="Ticker", period='2y', interval='1d')
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data) # fitting the collected data to the list

# combine all dataframes into a single dataframe
df = pd.concat(df_list)

# save to csv
df.to_csv('demonstration.csv')

df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Date
# 2020-10-19 00:00:00-04:00  164.980499  166.449997  159.636993  160.360504
# 2020-10-20 00:00:00-04:00  161.113998  163.300003  159.600494  160.850494
# 2020-10-21 00:00:00-04:00  160.625000  161.694000  158.000000  159.246994
# 2020-10-22 00:00:00-04:00  159.493500  159.937500  156.097000  158.820007
# 2020-10-23 00:00:00-04:00  159.550003  160.266495  157.000000  160.220001
#
#                             Adj Close     Volume ticker
# Date
# 2020-10-19 00:00:00-04:00  160.360504  104472000   AMZN
# 2020-10-20 00:00:00-04:00  160.850494   90194000   AMZN
# 2020-10-21 00:00:00-04:00  159.246994   91854000   AMZN
# 2020-10-22 00:00:00-04:00  158.820007   84240000   AMZN
# 2020-10-23 00:00:00-04:00  160.220001   69334000   AMZN

# %%
# restructing the data as a pivot table for visualisation

df.pivot_table(index='Date',columns='ticker',values='Open').plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### 4.Q. Exercise of downloading data from multiple companies
#
# **<span style="color:green">Now it's your turn to practice: Can you download the daily stock price data of FORD, TOYOTA, and TESLA in recent 5 years and visualising them?</span>**

# %%
# Please show your code below:

Strings = ['F','TM', 'TSLA']
df_list = list() # creating an empty list
for ticker in Strings:
    data = yf.download(ticker, group_by="Ticker", period='5y', interval='1d')
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data) # fitting the collected data to the list

df2 = pd.concat(df_list)
    
df2.pivot_table(index='Date',columns='ticker',values='Open').plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <AxesSubplot:xlabel='Date'>
